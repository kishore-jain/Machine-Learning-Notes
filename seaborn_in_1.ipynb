# %%
# Advanced visualization using seaborn
import pandas as pd

df = pd.read_csv("http://media.sundog-soft.com/SelfDriving/FuelEfficiency.csv")

df
# Out:
#                 Mfr Name                 Carline  Eng Displ  Cylinders  \
# 0           aston martin              Vantage V8        4.0          8
# 1    Volkswagen Group of                  Chiron        8.0         16
# 2         General Motors                CORVETTE        6.2          8
# 3         General Motors                CORVETTE        6.2          8
# 4         General Motors                CORVETTE        6.2          8
# ..                   ...                     ...        ...        ...
# 713               Toyota             4RUNNER 4WD        4.0          6
# 714               Toyota  LAND CRUISER WAGON 4WD        5.7          8
# 715               Toyota             SEQUOIA 4WD        5.7          8
# 716                Volvo                XC90 AWD        2.0          4
# 717                Volvo                XC90 AWD        2.0          4
#
#     Transmission  CityMPG  HwyMPG  CombMPG  # Gears
# 0       Auto(S8)       18      25       21        8
# 1    Auto(AM-S7)        9      14       11        7
# 2       Auto(S8)       12      20       15        8
# 3       Auto(S8)       15      25       18        8
# 4       Auto(S8)       14      23       17        8
# ..           ...      ...     ...      ...      ...
# 713     Auto(S5)       17      20       18        5
# 714     Auto(S8)       13      18       15        8
# 715     Auto(S6)       13      17       14        6
# 716     Auto(S8)       19      26       22        8
# 717     Auto(S8)       20      27       23        8
#
# [718 rows x 9 columns]

# %%
count = df['# Gears'].value_counts()
print(count)
print(count.plot(kind='pie'))
count.plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 count = df['# Gears'].value_counts()
#       2 print(count)
#       3 print(count.plot(kind='pie'))
#
# NameError: name 'df' is not defined

# %%
import seaborn as sns
sns.set()
count.plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns
sns.set()
count.plot(kind='bar')
# Out:
# <Axes: xlabel='# Gears'>

# %%
df.head(10)
# Out:
#               Mfr Name     Carline  Eng Displ  Cylinders Transmission  \
# 0         aston martin  Vantage V8        4.0          8     Auto(S8)
# 1  Volkswagen Group of      Chiron        8.0         16  Auto(AM-S7)
# 2       General Motors    CORVETTE        6.2          8     Auto(S8)
# 3       General Motors    CORVETTE        6.2          8     Auto(S8)
# 4       General Motors    CORVETTE        6.2          8     Auto(S8)
# 5       General Motors    CORVETTE        6.2          8   Manual(M7)
# 6       General Motors    CORVETTE        6.2          8   Manual(M7)
# 7       General Motors    CORVETTE        6.2          8   Manual(M7)
# 8              Ferrari     488 gtb        3.9          8    Auto(AM7)
# 9              Ferrari     488 gtb        3.9          8    Auto(AM7)
#
#    CityMPG  HwyMPG  CombMPG  # Gears
# 0       18      25       21        8
# 1        9      14       11        7
# 2       12      20       15        8
# 3       15      25       18        8
# 4       14      23       17        8
# 5       13      19       15        7
# 6       15      22       17        7
# 7       16      25       19        7
# 8       16      22       18        7
# 9       15      22       18        7

# %%
sns.distplot(df['CombMPG'])# shows distribution over combmpg based on velocity of car to reach mileage pickup
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7632\2108984681.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CombMPG'])# shows distribution over combmpg based on velocity of car to reach mileage pickup
# <Axes: xlabel='CombMPG', ylabel='Density'>

# %%
sns.distplot(df['HwyMPG'])
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7632\4095843134.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['HwyMPG'])
# <Axes: xlabel='HwyMPG', ylabel='Density'>

# %%
sns.distplot(df['CityMPG'])
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7632\3077767107.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['CityMPG'])
# <Axes: xlabel='CityMPG', ylabel='Density'>

# %%
sns.distplot(df['HwyMPG'])
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7632\4095843134.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['HwyMPG'])
# <Axes: xlabel='HwyMPG', ylabel='Density'>

# %%
# relationship between cylinders, city MPG, high MPG, and combined MPG

df2 = df[['Cylinders','CityMPG','HwyMPG','CombMPG']]
print(type(df2))
print(df2.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# (718, 4)

# %%
df2.head(10)
# Out:
#    Cylinders  CityMPG  HwyMPG  CombMPG
# 0          8       18      25       21
# 1         16        9      14       11
# 2          8       12      20       15
# 3          8       15      25       18
# 4          8       14      23       17
# 5          8       13      19       15
# 6          8       15      22       17
# 7          8       16      25       19
# 8          8       16      22       18
# 9          8       15      22       18

# %%
sns.pairplot(df2,height=2)

# %%
# combined milleage scatter plot

sns.scatterplot(x='Cylinders',y='CombMPG',data=df2)
# Out:
# <Axes: xlabel='Cylinders', ylabel='CombMPG'>

# %%
sns.jointplot(x='Cylinders',y='CityMPG',data=df2)

# %%
#LM plot # and linear regression mode fit plot(face grid)
sns.lmplot(x='Cylinders',y='CombMPG',data=df2)

# %%
sns.jointplot(x='Cylinders',y='HwyMPG',data=df2)

# %%
# whisker plot
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.boxplot(x='Mfr Name',y='CombMPG',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# Out:
# C:\Python312\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7632\2361807551.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %%
# swarmp plot
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.swarmplot(x='Mfr Name',y='CombMPG',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# Out:
# C:\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 46.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 21.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 14.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 46.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 45.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 12.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 7.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7632\4047965376.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 31.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 6.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 30.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 29.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# count plot
sns.set(rc={'figure.figsize':(15,5)})
ax = sns.countplot(x='Mfr Name',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# Out:
# C:\Users\ELCOT\AppData\Local\Temp\ipykernel_7632\4150379109.py:4: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# [Text(0, 0, 'aston martin'),
#  Text(1, 0, 'Volkswagen Group of'),
#  Text(2, 0, 'General Motors'),
#  Text(3, 0, 'Ferrari'),
#  Text(4, 0, 'FCA US LLC'),
#  Text(5, 0, 'Jaguar Land Rover L'),
#  Text(6, 0, 'MAZDA'),
#  Text(7, 0, 'Nissan'),
#  Text(8, 0, 'Porsche'),
#  Text(9, 0, 'BMW'),
#  Text(10, 0, 'Subaru'),
#  Text(11, 0, 'Toyota'),
#  Text(12, 0, 'Ford Motor Company'),
#  Text(13, 0, 'Mercedes-Benz'),
#  Text(14, 0, 'Honda'),
#  Text(15, 0, 'Hyundai'),
#  Text(16, 0, 'Rolls-Royce'),
#  Text(17, 0, 'Volvo'),
#  Text(18, 0, 'Kia'),
#  Text(19, 0, 'Maserati'),
#  Text(20, 0, 'Mitsubishi Motors Co')]

# %%
# heatmap
df2 = df.pivot_table(index='Cylinders',columns = 'Eng Displ',values = 'CityMPG',aggfunc='mean')
sns.heatmap(df2) # data mapping is represented in color
# Out:
# <Axes: xlabel='Eng Displ', ylabel='Cylinders'>

# %%
sns.scatterplot(x='# Gears',y='CombMPG',data=df)
# Out:
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %%
sns.lmplot(x='# Gears',y='CombMPG',data=df)

# %%
sns.jointplot(x='# Gears',y='CombMPG',data=df)

# %%
sns.boxplot(x='# Gears',y='CombMPG',data=df)
# Out:
# C:\Python312\Lib\site-packages\seaborn\categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# <Axes: xlabel='# Gears', ylabel='CombMPG'>

# %%
sns.swarmplot(x='# Gears',y='CombMPG',data=df)
# Out:
# C:\Python312\Lib\site-packages\seaborn\_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# C:\Python312\Lib\site-packages\seaborn\categorical.py:3398: UserWarning: 14.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='# Gears', ylabel='CombMPG'>
